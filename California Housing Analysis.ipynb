# %%
import pandas as pd 
import numpy as np 
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
data=pd.read_csv('housing2.csv')

# %%
data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0          880           129.0
# 1        -122.22     37.86                21.0         7099          1106.0
# 2        -122.24     37.85                52.0         1467           190.0
# 3        -122.25     37.85                52.0         1274           235.0
# 4        -122.25     37.85                 NaN         1627           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0         1665           374.0
# 20636    -121.21     39.49                18.0          697           150.0
# 20637    -121.22     39.43                17.0         2254           485.0
# 20638    -121.32     39.43                18.0         1860           409.0
# 20639    -121.24     39.37                16.0         2785           616.0
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20382 non-null  float64
#  3   total_rooms         20640 non-null  int64
#  4   total_bedrooms      15758 non-null  float64
#  5   population          20596 non-null  float64
#  6   households          19335 non-null  object
#  7   median_income       17873 non-null  float64
#  8   median_house_value  20640 non-null  int64
#  9   ocean_proximity     20640 non-null  object
#  10  gender              16620 non-null  object
# dtypes: float64(6), int64(2), object(3)
# memory usage: 1.7+ MB

# %%
data.describe(include='all')
# Out:
#            longitude      latitude  housing_median_age   total_rooms  \
# count   20640.000000  20640.000000        20382.000000  20640.000000
# unique           NaN           NaN                 NaN           NaN
# top              NaN           NaN                 NaN           NaN
# freq             NaN           NaN                 NaN           NaN
# mean     -119.569704     35.631861           28.676283   2635.763081
# std         2.003532      2.135952           12.589284   2181.615252
# min      -124.350000     32.540000            1.000000      2.000000
# 25%      -121.800000     33.930000           18.000000   1447.750000
# 50%      -118.490000     34.260000           29.000000   2127.000000
# 75%      -118.010000     37.710000           37.000000   3148.000000
# max      -114.310000     41.950000           52.000000  39320.000000
#
#         total_bedrooms    population households  median_income  \
# count     15758.000000  20596.000000      19335   17873.000000
# ...

# %%
data.isnull().sum()
# Out:
# longitude                0
# latitude                 0
# housing_median_age     258
# total_rooms              0
# total_bedrooms        4882
# population              44
# households            1305
# median_income         2767
# median_house_value       0
# ocean_proximity          0
# gender                4020
# dtype: int64

# %%
sns.heatmap(data.isnull(),cmap='bwr',cbar=True)
plt.show()

# %%
data.hist(bins=10 ,figsize=(14,10), color = 'Blue')
plt.show()

# %%
data.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88           41.000000          880           129.0
# 1    -122.22     37.86           21.000000         7099          1106.0
# 2    -122.24     37.85           52.000000         1467           190.0
# 3    -122.25     37.85           52.000000         1274           235.0
# 4    -122.25     37.85           28.676283         1627           280.0
#
#     population  households  median_income  median_house_value  \
# 0   322.000000       126.0         8.3252              452600
# 1  2401.000000      1138.0         8.3014              358500
# 2   496.000000       177.0         7.2574              352100
# 3   558.000000       219.0         5.6431              341300
# 4   801.811176       259.0         3.8462              342200
#
#    enc_ocean_proximity
# 0                    3
# 1                    3
# 2                    3
# 3                    3
# 4                    3

# %%
sns.lmplot(x="longitude", y="latitude", data=data,hue='housing_median_age',row='ocean_proximity',line_kws={"lw":0.1 ,'color': 'red'},height=5);

# %%
sns.relplot(data=data ,x="longitude", y="latitude", hue="housing_median_age",palette="hsv", hue_norm=(0,255), edgecolor=".7",height=5, sizes=(50, 250), size_norm=(-.2, .8),)

# %%
sns.boxplot(x="total_rooms",data=data,linewidth=1,orient="h",saturation=2, width=0.5, dodge=True, fliersize=5)
# Out:
# <AxesSubplot:xlabel='total_rooms'>

# %%
sns.boxplot(x="total_bedrooms",data=data,linewidth=1,orient="h",saturation=2, width=0.5, dodge=True, fliersize=5)
# Out:
# <AxesSubplot:xlabel='total_bedrooms'>

# %%
sns.boxplot(x="population",data=data,linewidth=1,orient="h",saturation=2, width=0.5, dodge=True, fliersize=5)
# Out:
# <AxesSubplot:xlabel='population'>

# %%
data.corr()
# Out:
#                     longitude  latitude  housing_median_age  total_rooms  \
# longitude            1.000000 -0.924664           -0.107447     0.044568
# latitude            -0.924664  1.000000            0.009773    -0.036100
# housing_median_age  -0.107447  0.009773            1.000000    -0.360441
# total_rooms          0.044568 -0.036100           -0.360441     1.000000
# total_bedrooms       0.071610 -0.062301           -0.336824     0.926709
# population           0.100390 -0.109222           -0.294245     0.856914
# median_income        0.011478 -0.103528           -0.117781     0.220357
# median_house_value  -0.045967 -0.144160            0.107378     0.134153
#
#                     total_bedrooms  population  median_income  \
# longitude                 0.071610    0.100390       0.011478
# latitude                 -0.062301   -0.109222      -0.103528
# housing_median_age       -0.336824   -0.294245      -0.117781
# ...

# %%
divide=data['total_bedrooms']/data['total_rooms']
divide
# Out:
# 0        0.146591
# 1        0.155797
# 2        0.129516
# 3        0.184458
# 4        0.172096
#            ...
# 20635    0.224625
# 20636    0.215208
# 20637    0.215173
# 20638    0.219892
# 20639    0.221185
# Length: 20640, dtype: float64

# %%
divide.mean()
# Out:
# 0.2161642669892059

# %%
total_bedroom_mean=divide.mean()

# %%
data['total_bedrooms'].fillna(total_bedroom_mean*data['total_rooms'],inplace=True)

# %%
data.isnull().sum()
# Out:
# longitude                0
# latitude                 0
# housing_median_age     258
# total_rooms              0
# total_bedrooms           0
# population              44
# households            1305
# median_income         2767
# median_house_value       0
# ocean_proximity          0
# gender                4020
# dtype: int64

# %%
diivide=data['population']/data['total_bedrooms']
diivide
# Out:
# 0        2.496124
# 1        2.170886
# 2        2.610526
# 3        2.374468
# 4             NaN
#            ...
# 20635    2.259358
# 20636    2.373333
# 20637    2.076289
# 20638    1.811736
# 20639    2.251623
# Length: 20640, dtype: float64

# %%
diivide.mean()
# Out:
# 2.863611343633395

# %%
total_population_mean=diivide.mean()

# %%
data['population'].fillna(total_population_mean*data['total_bedrooms'],inplace=True)

# %%
fill = {"housing_median_age":data['housing_median_age'].mean()}
data.fillna(fill,inplace=True)

# %%
sns.pairplot(data, hue="housing_median_age",palette='husl')

# %%
sns.histplot(data,x="median_house_value", hue="ocean_proximity",multiple="dodge",edgecolor="0.5",linewidth=0.1,log_scale=False,element='poly',kde=True,palette='Set1')
# Out:
# <AxesSubplot:xlabel='median_house_value', ylabel='Count'>

# %% [markdown]
# ## LabelEncoding for ocean_proximity

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %%
data['enc_ocean_proximity'] = le.fit_transform(data['ocean_proximity'])

# %%
le.classes_
# Out:
# array(['<1H OCEAN', 'INLAND', 'ISLAND', 'NEAR BAY', 'NEAR OCEAN'],
#       dtype=object)

# %%
le.fit_transform(data['ocean_proximity'])
# Out:
# array([3, 3, 3, ..., 1, 1, 1])

# %%
ocean_proximity = LabelEncoder()

# %%
type(ocean_proximity)
# Out:
# sklearn.preprocessing._label.LabelEncoder

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   longitude            20640 non-null  float64
#  1   latitude             20640 non-null  float64
#  2   housing_median_age   20640 non-null  float64
#  3   total_rooms          20640 non-null  int64
#  4   total_bedrooms       20640 non-null  float64
#  5   population           20640 non-null  float64
#  6   households           19335 non-null  object
#  7   median_income        17873 non-null  float64
#  8   median_house_value   20640 non-null  int64
#  9   ocean_proximity      20640 non-null  object
#  10  gender               16620 non-null  object
#  11  enc_ocean_proximity  20640 non-null  int32
# dtypes: float64(6), int32(1), int64(2), object(3)
# memory usage: 1.8+ MB

# %%
data.drop('ocean_proximity', axis=1, inplace=True)
data.drop('gender', axis=1, inplace=True)

# %%
data['households']= data['households'].replace('no',np.NaN)
data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88           41.000000          880           129.0
# 1        -122.22     37.86           21.000000         7099          1106.0
# 2        -122.24     37.85           52.000000         1467           190.0
# 3        -122.25     37.85           52.000000         1274           235.0
# 4        -122.25     37.85           28.676283         1627           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48           25.000000         1665           374.0
# 20636    -121.21     39.49           18.000000          697           150.0
# 20637    -121.22     39.43           17.000000         2254           485.0
# 20638    -121.32     39.43           18.000000         1860           409.0
# 20639    -121.24     39.37           16.000000         2785           616.0
#
# ...

# %%
data['households'] = pd.to_numeric(data['households'])

# %%
fill = {"households":data['households'].mean()}
fill = {"median_income":data['median_income'].mean()}

data.fillna(fill,inplace=True)

# %%
data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88           41.000000          880           129.0
# 1        -122.22     37.86           21.000000         7099          1106.0
# 2        -122.24     37.85           52.000000         1467           190.0
# 3        -122.25     37.85           52.000000         1274           235.0
# 4        -122.25     37.85           28.676283         1627           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48           25.000000         1665           374.0
# 20636    -121.21     39.49           18.000000          697           150.0
# 20637    -121.22     39.43           17.000000         2254           485.0
# 20638    -121.32     39.43           18.000000         1860           409.0
# 20639    -121.24     39.37           16.000000         2785           616.0
#
# ...

# %%
data.isnull().sum()
# Out:
# longitude              0
# latitude               0
# housing_median_age     0
# total_rooms            0
# total_bedrooms         0
# population             0
# households             0
# median_income          0
# median_house_value     0
# enc_ocean_proximity    0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   longitude            20640 non-null  float64
#  1   latitude             20640 non-null  float64
#  2   housing_median_age   20640 non-null  float64
#  3   total_rooms          20640 non-null  int64
#  4   total_bedrooms       20640 non-null  float64
#  5   population           20640 non-null  float64
#  6   households           20640 non-null  float64
#  7   median_income        20640 non-null  float64
#  8   median_house_value   20640 non-null  int64
#  9   enc_ocean_proximity  20640 non-null  int32
# dtypes: float64(7), int32(1), int64(2)
# memory usage: 1.5 MB

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()

# %%
Xd= sc.fit_transform(data[['housing_median_age','total_rooms','total_bedrooms','population','median_income','median_house_value','households','enc_ocean_proximity','longitude','latitude']])

# %%
Xd
# Out:
# array([[ 0.98510561, -0.8048191 , -0.95957191, ...,  1.2910888 ,
#         -1.32783522,  1.05254828],
#        [-0.61360947,  2.0458901 ,  1.25623435, ...,  1.2910888 ,
#         -1.32284391,  1.04318455],
#        [ 1.86439889, -0.53574589, -0.82122577, ...,  1.2910888 ,
#         -1.33282653,  1.03850269],
#        ...,
#        [-0.93335248, -0.17499526, -0.15217475, ..., -0.11673923,
#         -0.8237132 ,  1.77823747],
#        [-0.85341673, -0.35559977, -0.32454043, ..., -0.11673923,
#         -0.87362627,  1.77823747],
#        [-1.01328823,  0.06840827,  0.14492927, ..., -0.11673923,
#         -0.83369581,  1.75014627]])

# %% [markdown]
# ### Regression Model with Standard Scaled Values

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
X = data.drop('median_house_value',axis=1).values
Y = data['median_house_value'].values
X_train, X_test, y_train, y_test = train_test_split(X, Y, random_state=42)

ss = StandardScaler()
X_train_sc = ss.fit_transform(X_train)
X_test_sc = ss.transform(X_test)

lr = LinearRegression()
lr.fit(X_train_sc, y_train)
y_pred = lr.predict(X_test_sc)
y_pred
print(lr.score(X_train_sc, y_train))
print(lr.score(X_test_sc, y_test))
print(lr.intercept_)
print(lr.coef_)
# Out:
# 0.5967715518769192
# 0.5919638553078861
# 207034.89205424595
# [-103642.33896205 -106913.54904232   13098.15292633    1602.05473217
#    36643.9218372   -42767.87868918   11417.90151883   65635.71418583
#    -3278.33099609]

# %%
y_pred
# Out:
# array([ 52585.58255448, 181279.55672066, 293951.80486211, ...,
#        132957.09588802, 133154.41513509, 342367.40628702])

# %% [markdown]
# ### Regression Model with Original Values

# %%
from sklearn.model_selection import train_test_split
X = data.drop('median_house_value',axis=1).values
Y = data['median_house_value'].values
X_train, X_test, y_train, y_test = train_test_split(X,Y,test_size = 0.25 ,random_state=42)
X_train.shape,y_train.shape
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, y_train)
y_pred = regressor.predict(X_test)
print(regressor.score(X_train,y_train))
print(regressor.score(X_test,y_test))
print(regressor.intercept_)
print(regressor.coef_)
# Out:
# 0.5967715518769192
# 0.5919638553078871
# -4378373.314401191
# [-5.17596538e+04 -5.01028716e+04  1.04508221e+03  7.33962714e-01
#   8.33542479e+01 -3.74188448e+01  3.38445275e+01  3.62003912e+04
#  -2.31934006e+03]

# %%
y_pred
# Out:
# array([ 52585.58255449, 181279.55672068, 293951.80486213, ...,
#        132957.09588804, 133154.41513509, 342367.40628704])

# %% [markdown]
# ## Ridge Regression

# %%
from sklearn.linear_model import Ridge
ridge = Ridge()

ridge.fit(X_train, y_train)
# Out:
# Ridge()

# %%
print("Training set score: {:.2f}".format(ridge.score(X_train, y_train)))
print("Test set score: {:.2f}".format(ridge.score(X_test, y_test)))
# Out:
# Training set score: 0.60
# Test set score: 0.59

# %%
ridge10 = Ridge( alpha=10).fit(X_train, y_train)
print("Training set score: {:.2f}".format(ridge10.score(X_train, y_train)))
print("Test set score: {:.2f}".format(ridge10.score(X_test, y_test)))
# Out:
# Training set score: 0.60
# Test set score: 0.59

# %%
ridge01 = Ridge(alpha=0.6).fit(X_train, y_train)
print("Training set score: {:.2f}".format(ridge01.score(X_train, y_train)))
print("Test set score: {:.2f}".format(ridge01.score(X_test, y_test)))
# Out:
# Training set score: 0.60
# Test set score: 0.59

# %%
from sklearn.metrics import  r2_score

# %%
r2 = r2_score(y_test, y_pred)
r2
# Out:
# 0.5919638553078871

# %%
from sklearn.metrics import mean_squared_error

# %%
mse = mean_squared_error(y_test , y_pred)
mse
# Out:
# 5399208141.1555195

# %%
from sklearn.metrics import mean_absolute_percentage_error

# %%
mape = mean_absolute_percentage_error(y_test , y_pred)
mape
# Out:
# 0.34057710877361513

# %%
from sklearn.metrics import mean_absolute_error

# %%
mean_absolute_error(y_test , y_pred)
# Out:
# 54688.39945490245

# %% [markdown]
# ## OLS

# %%
import numpy as np
import statsmodels.api as sm

# %%
X2 = sm.add_constant(X)
est = sm.OLS(Y, X2)
est2 = est.fit()

# %%
print(est2.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.596
# Model:                            OLS   Adj. R-squared:                  0.596
# Method:                 Least Squares   F-statistic:                     3377.
# Date:                Mon, 06 Sep 2021   Prob (F-statistic):               0.00
# Time:                        15:33:21   Log-Likelihood:            -2.6052e+05
# No. Observations:               20640   AIC:                         5.211e+05
# Df Residuals:                   20630   BIC:                         5.211e+05
# Df Model:                           9
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -4.377e+06   6.65e+04    -65.863      0.000   -4.51e+06   -4.25e+06
# ...
